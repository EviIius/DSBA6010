# %%
# ### uncommnet these if this is the first time you use these packages ####
# !pip install pandas
# !pip install numpy
# !pip install scikit-learn
# !pip install seaborn
# !pip install pyod
# !pip install PiML
# Out:
# Requirement already satisfied: pandas in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: numpy in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (1.23.5)
# Requirement already satisfied: scikit-learn in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (1.3.2)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from scikit-learn) (1.23.5)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: seaborn in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from seaborn) (1.23.5)
# Requirement already satisfied: pandas>=1.2 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from seaborn) (1.5.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from seaborn) (3.7.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Requirement already satisfied: pyod in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (2.0.2)
# Requirement already satisfied: joblib in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from pyod) (1.4.2)
# Requirement already satisfied: matplotlib in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from pyod) (3.7.5)
# Requirement already satisfied: numpy>=1.19 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from pyod) (1.23.5)
# Requirement already satisfied: numba>=0.51 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from pyod) (0.56.4)
# Requirement already satisfied: scipy>=1.5.1 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from pyod) (1.10.1)
# Requirement already satisfied: scikit-learn>=0.22.0 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from pyod) (1.3.2)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from numba>=0.51->pyod) (0.39.1)
# Requirement already satisfied: setuptools in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from numba>=0.51->pyod) (57.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from scikit-learn>=0.22.0->pyod) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from matplotlib->pyod) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from matplotlib->pyod) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from matplotlib->pyod) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from matplotlib->pyod) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from matplotlib->pyod) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from matplotlib->pyod) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from matplotlib->pyod) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from matplotlib->pyod) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib->pyod) (1.16.0)
# Requirement already satisfied: PiML in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (0.6.0.post2)
# Requirement already satisfied: ipykernel in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from PiML) (6.29.5)
# Requirement already satisfied: ipywidgets>=7.7.0 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from PiML) (8.1.5)
# Requirement already satisfied: joblib>=1.1.0 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from PiML) (1.4.2)
# Requirement already satisfied: ipython>=7.12.0 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from PiML) (8.27.0)
# Requirement already satisfied: numpy<1.24.0,>=1.21.4 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from PiML) (1.23.5)
# Requirement already satisfied: scipy<=1.10.1,>=1.5.3 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from PiML) (1.10.1)
# Requirement already satisfied: pandas<2.0.0,>=1.3.5 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from PiML) (1.5.3)
# Requirement already satisfied: matplotlib<3.8.0,>=3.1.2 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from PiML) (3.7.5)
# Requirement already satisfied: seaborn>=0.11.2 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from PiML) (0.13.2)
# Requirement already satisfied: xlrd>=1.2.0 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from PiML) (2.0.1)
# Requirement already satisfied: scikit-learn<1.4.0,>=0.24.2 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from PiML) (1.3.2)
# Requirement already satisfied: xgboost>=1.4.2 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from PiML) (2.1.1)
# Requirement already satisfied: statsmodels>=0.12.2 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from PiML) (0.14.2)
# Requirement already satisfied: lime>=0.2.0.1 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from PiML) (0.2.0.1)
# Requirement already satisfied: shap>=0.39.0 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from PiML) (0.46.0)
# Requirement already satisfied: torch>=1.11.0 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from PiML) (2.4.1)
# Requirement already satisfied: pygam==0.8.0 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from PiML) (0.8.0)
# Requirement already satisfied: natsort>=8.2.0 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from PiML) (8.4.0)
# Requirement already satisfied: psutil>=5.9.0 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from PiML) (6.0.0)
# Requirement already satisfied: dill>=0.3.6 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from PiML) (0.3.8)
# Requirement already satisfied: packaging>=20.5 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from PiML) (24.1)
# Requirement already satisfied: networkx>=2.6.3 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from PiML) (3.3)
# Requirement already satisfied: numba<0.57.0 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from PiML) (0.56.4)
# Requirement already satisfied: jupyter-client<=7.4.9 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from PiML) (7.4.9)
# Requirement already satisfied: optbinning>=0.17.3 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from PiML) (0.19.0)
# Requirement already satisfied: momentchi2 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from PiML) (0.1.8)
# Requirement already satisfied: future in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from pygam==0.8.0->PiML) (1.0.0)
# Requirement already satisfied: progressbar2 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from pygam==0.8.0->PiML) (4.5.0)
# Requirement already satisfied: decorator in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from ipython>=7.12.0->PiML) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from ipython>=7.12.0->PiML) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from ipython>=7.12.0->PiML) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from ipython>=7.12.0->PiML) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from ipython>=7.12.0->PiML) (2.18.0)
# Requirement already satisfied: stack-data in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from ipython>=7.12.0->PiML) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from ipython>=7.12.0->PiML) (5.14.3)
# Requirement already satisfied: exceptiongroup in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from ipython>=7.12.0->PiML) (1.2.2)
# Requirement already satisfied: typing-extensions>=4.6 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from ipython>=7.12.0->PiML) (4.12.2)
# Requirement already satisfied: colorama in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from ipython>=7.12.0->PiML) (0.4.6)
# Requirement already satisfied: comm>=0.1.3 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from ipywidgets>=7.7.0->PiML) (0.2.2)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from ipywidgets>=7.7.0->PiML) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from ipywidgets>=7.7.0->PiML) (3.0.13)
# Requirement already satisfied: entrypoints in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from jupyter-client<=7.4.9->PiML) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from jupyter-client<=7.4.9->PiML) (5.7.2)
# Requirement already satisfied: nest-asyncio>=1.5.4 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from jupyter-client<=7.4.9->PiML) (1.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from jupyter-client<=7.4.9->PiML) (2.9.0.post0)
# Requirement already satisfied: pyzmq>=23.0 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from jupyter-client<=7.4.9->PiML) (26.2.0)
# Requirement already satisfied: tornado>=6.2 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from jupyter-client<=7.4.9->PiML) (6.4.1)
# Requirement already satisfied: tqdm in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from lime>=0.2.0.1->PiML) (4.66.5)
# Requirement already satisfied: scikit-image>=0.12 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from lime>=0.2.0.1->PiML) (0.24.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from matplotlib<3.8.0,>=3.1.2->PiML) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from matplotlib<3.8.0,>=3.1.2->PiML) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from matplotlib<3.8.0,>=3.1.2->PiML) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from matplotlib<3.8.0,>=3.1.2->PiML) (1.4.7)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from matplotlib<3.8.0,>=3.1.2->PiML) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from matplotlib<3.8.0,>=3.1.2->PiML) (3.1.4)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from numba<0.57.0->PiML) (0.39.1)
# Requirement already satisfied: setuptools in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from numba<0.57.0->PiML) (57.4.0)
# Requirement already satisfied: ortools>=9.4 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from optbinning>=0.17.3->PiML) (9.7.2996)
# Requirement already satisfied: ropwr>=1.0.0 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from optbinning>=0.17.3->PiML) (1.0.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from pandas<2.0.0,>=1.3.5->PiML) (2024.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from scikit-learn<1.4.0,>=0.24.2->PiML) (3.5.0)
# Requirement already satisfied: slicer==0.0.8 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from shap>=0.39.0->PiML) (0.0.8)
# Requirement already satisfied: cloudpickle in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from shap>=0.39.0->PiML) (3.0.0)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from statsmodels>=0.12.2->PiML) (0.5.6)
# Requirement already satisfied: filelock in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from torch>=1.11.0->PiML) (3.15.4)
# Requirement already satisfied: sympy in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from torch>=1.11.0->PiML) (1.13.2)
# Requirement already satisfied: jinja2 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from torch>=1.11.0->PiML) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from torch>=1.11.0->PiML) (2024.9.0)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from ipykernel->PiML) (1.8.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from jedi>=0.16->ipython>=7.12.0->PiML) (0.8.4)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from jupyter-core>=4.9.2->jupyter-client<=7.4.9->PiML) (4.2.2)
# Requirement already satisfied: pywin32>=300 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from jupyter-core>=4.9.2->jupyter-client<=7.4.9->PiML) (306)
# Requirement already satisfied: absl-py>=0.13 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from ortools>=9.4->optbinning>=0.17.3->PiML) (2.1.0)
# Requirement already satisfied: protobuf>=4.23.3 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from ortools>=9.4->optbinning>=0.17.3->PiML) (5.28.0)
# Requirement already satisfied: six in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from patsy>=0.5.6->statsmodels>=0.12.2->PiML) (1.16.0)
# Requirement already satisfied: wcwidth in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.12.0->PiML) (0.2.13)
# Requirement already satisfied: cvxpy>=1.1.14 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from ropwr>=1.0.0->optbinning>=0.17.3->PiML) (1.5.3)
# Requirement already satisfied: imageio>=2.33 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from scikit-image>=0.12->lime>=0.2.0.1->PiML) (2.35.1)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from scikit-image>=0.12->lime>=0.2.0.1->PiML) (2024.8.30)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from scikit-image>=0.12->lime>=0.2.0.1->PiML) (0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from jinja2->torch>=1.11.0->PiML) (2.1.5)
# Requirement already satisfied: python-utils>=3.8.1 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from progressbar2->pygam==0.8.0->PiML) (3.8.2)
# Requirement already satisfied: executing>=1.2.0 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from stack-data->ipython>=7.12.0->PiML) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from stack-data->ipython>=7.12.0->PiML) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from stack-data->ipython>=7.12.0->PiML) (0.2.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from sympy->torch>=1.11.0->PiML) (1.3.0)
# Requirement already satisfied: osqp>=0.6.2 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from cvxpy>=1.1.14->ropwr>=1.0.0->optbinning>=0.17.3->PiML) (0.6.7.post1)
# Requirement already satisfied: ecos>=2 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from cvxpy>=1.1.14->ropwr>=1.0.0->optbinning>=0.17.3->PiML) (2.0.14)
# Requirement already satisfied: clarabel>=0.5.0 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from cvxpy>=1.1.14->ropwr>=1.0.0->optbinning>=0.17.3->PiML) (0.9.0)
# Requirement already satisfied: scs>=3.2.4.post1 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from cvxpy>=1.1.14->ropwr>=1.0.0->optbinning>=0.17.3->PiML) (3.2.7)
# Requirement already satisfied: qdldl in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from osqp>=0.6.2->cvxpy>=1.1.14->ropwr>=1.0.0->optbinning>=0.17.3->PiML) (0.1.7.post4)

# %%
# mute warnings
import warnings
warnings.filterwarnings('ignore')

import sklearn as sk
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from scipy import stats
import statsmodels.api as sm

# %% [markdown]
# # Data set
# **We're going to use the Motor Trends Cars ("mtcars") data set that is built into the R programming language.**
# ```
# mpg - Miles per Gallon
# cyl - # of cylinders
# disp - displacement, in cubic inches
# hp - horsepower
# drat - driveshaft ratio
# wt - weight
# qsec - 1/4 mile time; a measure of acceleration
# vs - 'V' or straight - engine shape
# am - transmission; auto or manual
# gear - # of gears
# carb - # of carburetors.
# ```

# %%
# Load the dataset
df = pd.read_csv("mtcars.csv")

# Here we are going to use the "model" of the car as a the index to our dataframe
df.set_index('model', inplace=True)
df.head()
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# model
# Mazda RX4          21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag      21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710         22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive     21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#                    carb
# model
# Mazda RX4             4
# Mazda RX4 Wag         4
# Datsun 710            1
# Hornet 4 Drive        1
# Hornet Sportabout     2

# %%
# Descriptive statistics
df.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# 25%    16.892500   0.000000   0.000000   3.000000   2.0000
# 50%    17.710000   0.000000   0.000000   4.000000   2.0000
# 75%    18.900000   1.000000   1.000000   4.000000   4.0000
# max    22.900000   1.000000   1.000000   5.000000   8.0000

# %%
# Check whether there are any missing values
df.isnull().sum()
# Out:
# mpg     0
# cyl     0
# disp    0
# hp      0
# drat    0
# wt      0
# qsec    0
# vs      0
# am      0
# gear    0
# carb    0
# dtype: int64

# %%
# Heatmap based on standardized values
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(df)
scaled = scaler.fit_transform(df)
scaled_df = pd.DataFrame(scaled, columns=df.columns, index=df.index)
# scaled_df.abs().sum(axis=1)
df.style.background_gradient(cmap ='coolwarm', gmap=scaled_df, axis=None, vmin=-3, vmax=3)
# Out:
# <style type="text/css">
# #T_f13f7_row0_col0, #T_f13f7_row1_col0 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_f13f7_row0_col1, #T_f13f7_row1_col1, #T_f13f7_row3_col1, #T_f13f7_row5_col1, #T_f13f7_row9_col1, #T_f13f7_row10_col1, #T_f13f7_row29_col1, #T_f13f7_row30_col4 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_f13f7_row0_col2, #T_f13f7_row1_col2 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_f13f7_row0_col3, #T_f13f7_row1_col3, #T_f13f7_row3_col3, #T_f13f7_row21_col6, #T_f13f7_row27_col6, #T_f13f7_row31_col3 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_f13f7_row0_col4, #T_f13f7_row1_col4, #T_f13f7_row13_col5, #T_f13f7_row30_col2 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_f13f7_row0_col5, #T_f13f7_row5_col3, #T_f13f7_row11_col0 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_f13f7_row0_col6, #T_f13f7_row2_col3, #T_f13f7_row20_col5, #T_f13f7_row21_col0 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_f13f7_row0_col7, #T_f13f7_row1_col7, #T_f13f7_row4_col7, #T_f13f7_row6_col7, #T_f13f7_row11_col7, #T_f13f7_row12_col7, #T_f13f7_row13_col7, #T_f13f7_row14_col7, #T_f13f7_row15_col7, #T_f13f7_row16_col7, #T_f13f7_row21_col7, #T_f13f7_row22_col7, #T_f13f7_row23_col7, #T_f13f7_row24_col7, #T_f13f7_row26_col7, #T_f13f7_row28_col7, #T_f13f7_row29_col7, #T_f13f7_row30_col7 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_f13f7_row0_col8, #T_f13f7_row1_col8, #T_f13f7_row2_col8, #T_f13f7_row17_col8, #T_f13f7_row18_col8, #T_f13f7_row19_col8, #T_f13f7_row25_col0, #T_f13f7_row25_col8, #T_f13f7_row26_col8, #T_f13f7_row27_col8, #T_f13f7_row28_col8, #T_f13f7_row29_col8, #T_f13f7_row30_col8, #T_f13f7_row31_col8 {
#   background-color: #f7ac8e;
#   color: #000000;
# }
# #T_f13f7_row0_col9, #T_f13f7_row1_col9, #T_f13f7_row2_col6, #T_f13f7_row2_col9, #T_f13f7_row7_col9, #T_f13f7_row8_col9, #T_f13f7_row9_col9, #T_f13f7_row10_col9, #T_f13f7_row17_col9, #T_f13f7_row18_col9, #T_f13f7_row19_col9, #T_f13f7_row25_col9, #T_f13f7_row31_col6, #T_f13f7_row31_col9 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_f13f7_row0_col10, #T_f13f7_row1_col10, #T_f13f7_row6_col10, #T_f13f7_row9_col10, #T_f13f7_row10_col10, #T_f13f7_row14_col10, #T_f13f7_row15_col10, #T_f13f7_row16_col10, #T_f13f7_row23_col10, #T_f13f7_row28_col10 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_f13f7_row1_col5 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_f13f7_row1_col6, #T_f13f7_row4_col6, #T_f13f7_row12_col0 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_f13f7_row2_col0, #T_f13f7_row8_col0 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_f13f7_row2_col1, #T_f13f7_row7_col1, #T_f13f7_row7_col3, #T_f13f7_row8_col1, #T_f13f7_row17_col1, #T_f13f7_row17_col2, #T_f13f7_row18_col1, #T_f13f7_row19_col1, #T_f13f7_row20_col1, #T_f13f7_row25_col1, #T_f13f7_row25_col2, #T_f13f7_row26_col1, #T_f13f7_row27_col1, #T_f13f7_row31_col1 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_f13f7_row2_col2, #T_f13f7_row11_col4, #T_f13f7_row12_col4, #T_f13f7_row13_col4 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_f13f7_row2_col4 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_f13f7_row2_col5 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_f13f7_row2_col7, #T_f13f7_row3_col7, #T_f13f7_row5_col7, #T_f13f7_row7_col7, #T_f13f7_row8_col7, #T_f13f7_row9_col7, #T_f13f7_row10_col7, #T_f13f7_row17_col7, #T_f13f7_row18_col7, #T_f13f7_row19_col7, #T_f13f7_row20_col7, #T_f13f7_row25_col7, #T_f13f7_row27_col7, #T_f13f7_row31_col7 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_f13f7_row2_col10, #T_f13f7_row3_col10, #T_f13f7_row5_col10, #T_f13f7_row6_col6, #T_f13f7_row15_col4, #T_f13f7_row17_col10, #T_f13f7_row19_col10, #T_f13f7_row20_col10, #T_f13f7_row23_col0, #T_f13f7_row25_col10 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_f13f7_row3_col0, #T_f13f7_row3_col2, #T_f13f7_row4_col5, #T_f13f7_row9_col5, #T_f13f7_row10_col5, #T_f13f7_row22_col5, #T_f13f7_row31_col0 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_f13f7_row3_col4, #T_f13f7_row6_col0, #T_f13f7_row24_col4 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_f13f7_row3_col5, #T_f13f7_row15_col6 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_f13f7_row3_col6 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_f13f7_row3_col8, #T_f13f7_row4_col8, #T_f13f7_row5_col8, #T_f13f7_row6_col8, #T_f13f7_row7_col8, #T_f13f7_row8_col8, #T_f13f7_row9_col8, #T_f13f7_row10_col8, #T_f13f7_row11_col8, #T_f13f7_row12_col8, #T_f13f7_row13_col0, #T_f13f7_row13_col8, #T_f13f7_row14_col8, #T_f13f7_row15_col8, #T_f13f7_row16_col8, #T_f13f7_row20_col8, #T_f13f7_row21_col8, #T_f13f7_row22_col0, #T_f13f7_row22_col8, #T_f13f7_row23_col8, #T_f13f7_row24_col8, #T_f13f7_row26_col3 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_f13f7_row3_col9, #T_f13f7_row4_col9, #T_f13f7_row5_col9, #T_f13f7_row6_col9, #T_f13f7_row11_col9, #T_f13f7_row12_col9, #T_f13f7_row13_col9, #T_f13f7_row14_col9, #T_f13f7_row15_col9, #T_f13f7_row16_col9, #T_f13f7_row20_col9, #T_f13f7_row21_col9, #T_f13f7_row22_col9, #T_f13f7_row23_col9, #T_f13f7_row24_col9 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_f13f7_row4_col0, #T_f13f7_row11_col6, #T_f13f7_row16_col6 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_f13f7_row4_col1, #T_f13f7_row6_col1, #T_f13f7_row11_col1, #T_f13f7_row12_col1, #T_f13f7_row13_col1, #T_f13f7_row14_col1, #T_f13f7_row15_col1, #T_f13f7_row15_col3, #T_f13f7_row16_col1, #T_f13f7_row21_col1, #T_f13f7_row22_col1, #T_f13f7_row23_col1, #T_f13f7_row24_col1, #T_f13f7_row28_col1, #T_f13f7_row30_col1 {
#   background-color: #f7b79b;
#   color: #000000;
# }
# #T_f13f7_row4_col2, #T_f13f7_row6_col2 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_f13f7_row4_col3, #T_f13f7_row24_col3, #T_f13f7_row29_col3 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_f13f7_row4_col4, #T_f13f7_row22_col4, #T_f13f7_row30_col0 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_f13f7_row4_col10, #T_f13f7_row7_col10, #T_f13f7_row8_col10, #T_f13f7_row18_col10, #T_f13f7_row21_col10, #T_f13f7_row22_col10, #T_f13f7_row24_col10, #T_f13f7_row26_col10, #T_f13f7_row27_col3, #T_f13f7_row27_col10, #T_f13f7_row31_col10 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_f13f7_row5_col0, #T_f13f7_row9_col3, #T_f13f7_row10_col3 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_f13f7_row5_col2, #T_f13f7_row8_col5, #T_f13f7_row28_col5, #T_f13f7_row29_col0 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_f13f7_row5_col4, #T_f13f7_row21_col4 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_f13f7_row5_col5, #T_f13f7_row9_col6, #T_f13f7_row20_col0, #T_f13f7_row23_col4 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_f13f7_row5_col6 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_f13f7_row6_col3, #T_f13f7_row23_col3 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_f13f7_row6_col4, #T_f13f7_row8_col2, #T_f13f7_row20_col3 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_f13f7_row6_col5, #T_f13f7_row11_col2, #T_f13f7_row12_col2, #T_f13f7_row13_col2, #T_f13f7_row30_col5 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_f13f7_row7_col0, #T_f13f7_row21_col2 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_f13f7_row7_col2, #T_f13f7_row16_col4, #T_f13f7_row29_col2 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_f13f7_row7_col4 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_f13f7_row7_col5 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_f13f7_row7_col6, #T_f13f7_row16_col3, #T_f13f7_row20_col6 {
#   background-color: #f7aa8c;
#   color: #000000;
# }
# #T_f13f7_row8_col3 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_f13f7_row8_col4, #T_f13f7_row9_col4, #T_f13f7_row10_col4 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_f13f7_row8_col6 {
#   background-color: #bb1b2c;
#   color: #f1f1f1;
# }
# #T_f13f7_row9_col0, #T_f13f7_row12_col6, #T_f13f7_row24_col0 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_f13f7_row9_col2, #T_f13f7_row10_col2 {
#   background-color: #c

# %% [markdown]
# # Use regression models to predict fuel comsumption(mpg)

# %%
from sklearn import  linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# #### split the dataset into training and test sets

# %%
X_train, X_test, y_train, y_test = train_test_split(
    df.iloc[:,1:], df.iloc[:,0], test_size=0.1, random_state=42)

# %% [markdown]
# ## Linear Regression

# %%
# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets
regr.fit(X_train, y_train)
print(X_train.columns)
print(regr.coef_)
#Predict using the test set
pred = regr.predict(X_test)

#Calculate the metrics for regression
reg_r2 = r2_score(y_test, pred)
reg_mse = mean_squared_error(y_test, pred)
print('------------')
print(reg_r2, reg_mse)
# Out:
# Index(['cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear', 'carb'], dtype='object')
# [-0.40110818  0.01316612 -0.02167558  0.59836675 -3.83000087  0.70898298
#   0.07163707  1.57941842  0.659154    0.0778369 ]
# ------------
# 0.8383955580471787 9.935744099588113

# %% [markdown]
# ## SVM for regression

# %%
from sklearn.svm import SVR
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

# %%
# Create svm regression object
regr_svm = make_pipeline(StandardScaler(), SVR(kernel='linear',C=1.0, epsilon=0.2))

# Train the model using the training sets
regr_svm.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('svr', SVR(epsilon=0.2, kernel='linear'))])

# %%
#Predict using the test set
pred = regr_svm.predict(X_test)

#Calculate the metrics for regression
svm_r2 = r2_score(y_test, pred)
svm_mse = mean_squared_error(y_test, pred)

# %%
print(svm_r2, svm_mse)
# Out:
# 0.784034144131135 13.27798575479757

# %% [markdown]
# ## Gradient Boosting for regression

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
# Create gradient boosting regression object
reg_gb = GradientBoostingRegressor(random_state=0)

# Train the model using the training sets
reg_gb.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(random_state=0)

# %%
#Predict using the test set
pred = reg_gb.predict(X_test)

#Calculate the metrics for regression
gb_r2 = r2_score(y_test, pred)
gb_mse = mean_squared_error(y_test, pred)

# %%
#Make a table to compare the performance of different models
pd.DataFrame({'LinearRegression':[reg_r2,reg_mse], 'SVM':[svm_r2, svm_mse],  'GradientBoosting':[gb_r2, gb_mse]}, index=['R2', 'MSE'])
# Out:
#      LinearRegression        SVM  GradientBoosting
# R2           0.838396   0.784034          0.876541
# MSE          9.935744  13.277986          7.590488

# %% [markdown]
# ## Outlier Detection: univariate case

# %%
plt.figure(figsize=(12, 8))


for i, col in enumerate(df.columns):
    plt.subplot(3, 4, i+1)  # Create a 3x4 grid of subplots
    sns.boxplot(x=df[col])
    plt.title(f'Boxplot of {col}')

plt.tight_layout()
plt.show()

# %%
# Find the outliers for "wt"
wtQ1 = df['wt'].quantile(0.25)
wtQ3 = df['wt'].quantile(0.75)
wtIQR = wtQ3 - wtQ1    #IQR is interquartile range.
print(wtQ1, wtQ3, wtIQR)

wt_upper_limit = (wtQ3 + 1.5 * wtIQR)
wt_lower_limit = (wtQ1 - 1.5 * wtIQR)
# Show the boxplot outliers
df.loc[(df['wt'] < wt_lower_limit) | (df['wt'] > wt_upper_limit)]
# Out:
# 2.58125 3.61 1.02875
#                       mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# model
# Cadillac Fleetwood   10.4    8  472.0  205  2.93  5.250  17.98   0   0     3
# Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   0   0     3
# Chrysler Imperial    14.7    8  440.0  230  3.23  5.345  17.42   0   0     3
#
#                      carb
# model
# Cadillac Fleetwood      4
# Lincoln Continental     4
# Chrysler Imperial       4

# %%
# Find the outliers for "hp" and "qsec"
# hp
hpQ1 = df['hp'].quantile(0.25)
hpQ3 = df['hp'].quantile(0.75)
hpIQR = hpQ3 - hpQ1    #IQR is interquartile range.
print(hpQ1, hpQ3, hpIQR)

hp_upper_limit = (hpQ3 + 1.5 * hpIQR)
hp_lower_limit = (hpQ1 - 1.5 * hpIQR)
# Show the boxplot outliers
df.loc[(df['hp'] < hp_lower_limit) | (df['hp'] > hp_upper_limit)]
# Out:
# 96.5 180.0 83.5
#                 mpg  cyl   disp   hp  drat    wt  qsec  vs  am  gear  carb
# model
# Maserati Bora  15.0    8  301.0  335  3.54  3.57  14.6   0   1     5     8

# %%
#qsec
qsecQ1 = df['qsec'].quantile(0.25)
qsecQ3 = df['qsec'].quantile(0.75)
qsecIQR = qsecQ3 - qsecQ1    #IQR is interquartile range.
print(qsecQ1, qsecQ3, qsecIQR)

qsec_upper_limit = (qsecQ3 + 1.5 * qsecIQR)
qsec_lower_limit = (qsecQ1 - 1.5 * qsecIQR)
# Show the boxplot outliers
df.loc[(df['qsec'] < qsec_lower_limit) | (df['qsec'] > qsec_upper_limit)]
# Out:
# 16.8925 18.9 2.0075000000000003
#            mpg  cyl   disp  hp  drat    wt  qsec  vs  am  gear  carb
# model
# Merc 230  22.8    4  140.8  95  3.92  3.15  22.9   1   0     4     2

# %% [markdown]
# ## Outlier Treatments

# %% [markdown]
# ### Capping Outliers (using IQR)

# %%
df2 = X_train.copy()

# %%
# This code will "cap" (or floor) the outliers to our limit for the wt predictor
df2['wt'] = np.where(df2['wt'] > wt_upper_limit,
  wt_upper_limit,
  np.where(
    df2['wt'] < wt_lower_limit,
    wt_lower_limit,
    df2['wt']
   )
)

# %%
# Write code to cap/floor the hp and qsec predictors
# hp
df2['hp'] = np.where(df2['hp'] > hp_upper_limit,
  hp_upper_limit,
  np.where(
    df2['hp'] < hp_lower_limit,
    hp_lower_limit,
    df2['hp']
   )
)

# %%
#qsec
df2['qsec'] = np.where(df2['qsec'] > qsec_upper_limit,
  qsec_upper_limit,
  np.where(
    df2['qsec'] < qsec_lower_limit,
    qsec_lower_limit,
    df2['qsec']
   )
)

# %%
# Use describe to ensure our min/max looks right
df2.describe()
# Out:
#              cyl        disp          hp       drat         wt       qsec  \
# count  28.000000   28.000000   28.000000  28.000000  28.000000  28.000000
# mean    6.142857  224.978571  144.044643   3.618214   3.158009  17.868973
# std     1.799471  116.042580   67.338698   0.544066   0.900980   1.733991
# min     4.000000   71.100000   52.000000   2.760000   1.513000  14.500000
# 25%     4.000000  120.825000   96.500000   3.132500   2.581250  16.892500
# 50%     6.000000  196.300000  118.000000   3.715000   3.325000  17.790000
# 75%     8.000000  307.500000  180.000000   3.920000   3.570000  18.900000
# max     8.000000  472.000000  305.250000   4.930000   5.153125  21.911250
#
#               vs         am       gear       carb
# count  28.000000  28.000000  28.000000  28.000000
# mean    0.464286   0.392857   3.678571   2.750000
# std     0.507875   0.497347   0.722832   1.554563
# min     0.000000   0.000000   3.000000   1.000000
# 25%     0.000000   0.000000   3.000000   2.000000
# 50%     0.000000   0.000000   4.000000   2.000000
# 75%     1.000000   1.000000   4.000000   4.000000
# max     1.000000   1.000000   5.000000   8.000000

# %%
########### Linear Regression ############
regr = linear_model.LinearRegression()
regr.fit(df2, y_train)
pred = regr.predict(X_test)
reg_r2_capped = r2_score(y_test, pred)
reg_mse_capped = mean_squared_error(y_test, pred)

#################### SVM ####################
regr_svm = make_pipeline(StandardScaler(), SVR(kernel='linear',C=1.0, epsilon=0.2))
regr_svm.fit(df2, y_train)
pred = regr_svm.predict(X_test)
svm_r2_capped = r2_score(y_test, pred)
svm_mse_capped = mean_squared_error(y_test, pred)

#################### Gradient Boosting ####################
reg_gb = GradientBoostingRegressor(random_state=0)
reg_gb.fit(df2, y_train)
pred = reg_gb.predict(X_test)
gb_r2_capped = r2_score(y_test, pred)
gb_mse_capped = mean_squared_error(y_test, pred)

# %%
# compare metrics: no treatment VS "capped"
pd.DataFrame(
    {'LinearRegression':[reg_r2,reg_r2_capped],
        'SVM':[svm_r2, svm_r2_capped],
        'GradientBoosting':[gb_r2, gb_r2_capped]},
    index=['R2', 'R2_capped'])
# Out:
#            LinearRegression       SVM  GradientBoosting
# R2                 0.838396  0.784034          0.876541
# R2_capped          0.840594  0.780404          0.880187

# %%
pd.DataFrame(
    {'LinearRegression':[reg_mse,reg_mse_capped],
     'SVM':[svm_mse, svm_mse_capped],
     'GradientBoosting':[gb_mse, gb_mse_capped]},
    index=['MSE', 'MSE_capped'])
# Out:
#             LinearRegression        SVM  GradientBoosting
# MSE                 9.935744  13.277986          7.590488
# MSE_capped          9.800564  13.501195          7.366320

# %% [markdown]
# ### Removing rows with outliers

# %%
df3 = X_train.copy()

# %%
# This code will remove outliers beyond our limit for the wt predictor
y_train.drop(y_train[(df3.wt < wt_lower_limit) | (df3.wt > wt_upper_limit)].index, inplace=True)
df3.drop(df3[df3.wt < wt_lower_limit].index, inplace=True)
df3.drop(df3[df3.wt > wt_upper_limit].index, inplace=True)

# %%
# Write code to remove outliers beyond our limit for the hp and qsec predictors
#hp
y_train.drop(y_train[(df3.hp < hp_lower_limit) | (df3.hp > hp_upper_limit)].index, inplace=True)
df3.drop(df3[df3.hp < hp_lower_limit].index, inplace=True)
df3.drop(df3[df3.hp > hp_upper_limit].index, inplace=True)

# %%
#qsec
y_train.drop(y_train[(df3.qsec < qsec_lower_limit) | (df3.qsec > qsec_upper_limit)].index, inplace=True)
df3.drop(df3[df3.qsec < qsec_lower_limit].index, inplace=True)
df3.drop(df3[df3.qsec > qsec_upper_limit].index, inplace=True)

# %%
# Use describe to ensure our min/max looks right
df3.describe()
# Out:
#              cyl        disp          hp       drat         wt       qsec  \
# count  24.000000   24.000000   24.000000  24.000000  24.000000  24.000000
# mean    6.000000  206.066667  133.250000   3.653750   2.974917  17.850833
# std     1.769303  101.054405   59.027812   0.561069   0.751299   1.531319
# min     4.000000   71.100000   52.000000   2.760000   1.513000  14.500000
# 25%     4.000000  120.250000   96.000000   3.132500   2.428750  16.892500
# 50%     6.000000  167.600000  111.500000   3.750000   3.202500  17.800000
# 75%     8.000000  282.850000  176.250000   3.960000   3.475000  18.900000
# max     8.000000  360.000000  264.000000   4.930000   4.070000  20.220000
#
#               vs         am       gear       carb
# count  24.000000  24.000000  24.000000  24.000000
# mean    0.500000   0.416667   3.666667   2.458333
# std     0.510754   0.503610   0.701964   1.178767
# min     0.000000   0.000000   3.000000   1.000000
# 25%     0.000000   0.000000   3.000000   1.750000
# 50%     0.500000   0.000000   4.000000   2.000000
# 75%     1.000000   1.000000   4.000000   4.000000
# max     1.000000   1.000000   5.000000   4.000000

# %%
########### Linear Regression ############
regr = linear_model.LinearRegression()
regr.fit(df3, y_train)
pred = regr.predict(X_test)
reg_r2_removed = r2_score(y_test, pred)
reg_mse_removed = mean_squared_error(y_test, pred)

#################### SVM ####################
regr_svm = make_pipeline(StandardScaler(), SVR(kernel='linear',C=1.0, epsilon=0.2))
regr_svm.fit(df3, y_train)
pred = regr_svm.predict(X_test)
svm_r2_removed = r2_score(y_test, pred)
svm_mse_removed = mean_squared_error(y_test, pred)

#################### Gradient Boosting ####################
reg_gb = GradientBoostingRegressor(random_state=0)
reg_gb.fit(df3, y_train)
pred = reg_gb.predict(X_test)
gb_r2_removed = r2_score(y_test, pred)
gb_mse_removed = mean_squared_error(y_test, pred)

# %%
# compare metrics: no treatment VS "capped" VS "removed"
pd.DataFrame(
    {'LinearRegression':[reg_r2,reg_r2_capped,reg_r2_removed],
        'SVM':[svm_r2, svm_r2_capped, svm_r2_removed],
        'GradientBoosting':[gb_r2, gb_r2_capped, gb_r2_removed]},
    index=['R2', 'R2_capped', 'R2_removed'])
# Out:
#             LinearRegression       SVM  GradientBoosting
# R2                  0.838396  0.784034          0.876541
# R2_capped           0.840594  0.780404          0.880187
# R2_removed          0.714471  0.782641          0.722095

# %%
pd.DataFrame(
    {'LinearRegression':[reg_mse,reg_mse_capped,reg_mse_removed],
     'SVM':[svm_mse, svm_mse_capped, svm_mse_removed],
     'GradientBoosting':[gb_mse, gb_mse_capped, gb_mse_removed]},
    index=['MSE', 'MSE_capped', 'MSE_removed'])
# Out:
#              LinearRegression        SVM  GradientBoosting
# MSE                  9.935744  13.277986          7.590488
# MSE_capped           9.800564  13.501195          7.366320
# MSE_removed         17.554841  13.363656         17.086114

# %% [markdown]
# ## Outlier Detection: multivariate case

# %%
# If not already installed, install pyod
# !pip install pyod
# Out:
# Requirement already satisfied: pyod in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (2.0.2)
# Requirement already satisfied: joblib in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from pyod) (1.4.2)
# Requirement already satisfied: matplotlib in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from pyod) (3.7.5)
# Requirement already satisfied: numpy>=1.19 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from pyod) (1.23.5)
# Requirement already satisfied: numba>=0.51 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from pyod) (0.56.4)
# Requirement already satisfied: scipy>=1.5.1 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from pyod) (1.10.1)
# Requirement already satisfied: scikit-learn>=0.22.0 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from pyod) (1.3.2)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from numba>=0.51->pyod) (0.39.1)
# Requirement already satisfied: setuptools in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from numba>=0.51->pyod) (57.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from scikit-learn>=0.22.0->pyod) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from matplotlib->pyod) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from matplotlib->pyod) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from matplotlib->pyod) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from matplotlib->pyod) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from matplotlib->pyod) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from matplotlib->pyod) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from matplotlib->pyod) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from matplotlib->pyod) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\rbrul\documents\github\dsba6010\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib->pyod) (1.16.0)

# %%
# use LOF (with 5 nearest neighbors) to detection multivariate outliers
# and eliminate rows with and lof score > 1.3
from pyod.models.lof import LOF

df4 = df.copy()

# Prepare the LOF model with 5 nearest neighbors
lof = LOF(n_neighbors=5)

# Fit the LOF model and predict the outliers
lof.fit(df4)
lof_scores = lof.decision_scores_

# Add the LOF scores to the dataframe
df4['LOF_Value'] = lof_scores
df4
# Out:
#                       mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# model
# Mazda RX4            21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag        21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710           22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive       21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout    18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# Valiant              18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# Duster 360           14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# Merc 240D            24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# Merc 230             22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# Merc 280             19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
# Merc 280C            17.8    6  167.6  123  3.92  3.440  18.90   1   0     4
# Merc 450SE           16.4    8  275.8  180  3.07  4.070  17.40   0   0     3
# Merc 450SL           17.3    8  275.8  180  3.07  3.730  17.60   0   0     3
# Merc 450SLC          15.2    8  275.8  180  3.07  3.780  18.00   0   0     3
# Cadillac Fleetwood   10.4    8  472.0  205  2.93  5.250  17.98   0   0     3
# Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   0   0     3
# Chrysler Imperial    14.7    8  440.0  230  3.23  5.345  17.42   0   0     3
# Fiat 128             32.4    4   78.7   66  4.08  2.200  19.47   1   1     4
# Honda Civic          30.4    4   75.7   52  4.93  1.615  18.52   1   1     4
# Toyota Corolla       33.9    4   71.1   65  4.22  1.835  19.90   1   1     4
# Toyota Corona        21.5    4  120.1   97  3.70  2.465  20.01   1   0     3
# Dodge Challenger     15.5    8  318.0  150  2.76  3.520  16.87   0   0     3
# AMC Javelin          15.2    8  304.0  150  3.15  3.435  17.30   0   0     3
# Camaro Z28           13.3    8  350.0  245  3.73  3.840  15.41   0   0     3
# Pontiac Firebird     19.2    8  400.0  175  3.08  3.845  17.05   0   0     3
# Fiat X1-9            27.3    4   79.0   66  4.08  1.935  18.90   1   1     4
# Porsche 914-2        26.0    4  120.3   91  4.43  2.140  16.70   0   1     5
# Lotus Europa         30.4    4   95.1  113  3.77  1.513  16.90   1   1     5
# Ford Pantera L       15.8    8  351.0  264  4.22  3.170  14.50   0   1     5
# Ferrari Dino         19.7    6  145.0  175  3.62  2.770  15.50   0   1     5
# Maserati Bora        15.0    8  301.0  335  3.54  3.570  14.60   0   1     5
# Volvo 142E           21.4    4  121.0  109  4.11  2.780  18.60   1   1     4
#
#                      carb  LOF_Value
# model
# Mazda RX4               4   1.041947
# Mazda RX4 Wag           4   1.041947
# Datsun 710              1   1.024865
# Hornet 4 Drive          1   1.026977
# Hornet Sportabout       2   0.923277
# Valiant                 1   1.432937
# Duster 360              4   0.964717
# Merc 240D               2   1.229866
# Merc 230                2   0.942760
# Merc 280                4   1.127189
# Merc 280C               4   1.127728
# Merc 450SE              3   0.974647
# Merc 450SL              3   0.974878
# Merc 450SLC             3   0.974647
# Cadillac Fleetwood      4   1.159139
# Lincoln Continental     4   1.128107
# Chrysler Imperial       4   1.031167
# Fiat 128                1   1.173683
# Honda Civic             2   1.237937
# Toyota Corolla          1   1.195461
# Toyota Corona           1   0.984568
# Dodge Challenger        2   1.030133
# AMC Javelin             2   1.014205
# Camaro Z28              4   0.952798
# Pontiac Firebird        2   1.041303
# Fiat X1-9               1   1.167617
# Porsche 914-2           2   0.967056
# Lotus Europa            2   0.959718
# Ford Pantera L          4   1.142798
# Ferrari Dino            6   1.587094
# Maserati Bora           8   1.570968
# Volvo 142E              2   1.008551

# %%
# Sort the dataframe by the LOF_Value column in descending order
df4_sorted = df4.sort_values(by='LOF_Value', ascending=False)
df4_sorted
# Out:
#                       mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# model
# Ferrari Dino         19.7    6  145.0  175  3.62  2.770  15.50   0   1     5
# Maserati Bora        15.0    8  301.0  335  3.54  3.570  14.60   0   1     5
# Valiant              18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# Honda Civic          30.4    4   75.7   52  4.93  1.615  18.52   1   1     4
# Merc 240D            24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# Toyota Corolla       33.9    4   71.1   65  4.22  1.835  19.90   1   1     4
# Fiat 128             32.4    4   78.7   66  4.08  2.200  19.47   1   1     4
# Fiat X1-9            27.3    4   79.0   66  4.08  1.935  18.90   1   1     4
# Cadillac Fleetwood   10.4    8  472.0  205  2.93  5.250  17.98   0   0     3
# Ford Pantera L       15.8    8  351.0  264  4.22  3.170  14.50   0   1     5
# Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   0   0     3
# Merc 280C            17.8    6  167.6  123  3.92  3.440  18.90   1   0     4
# Merc 280             19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
# Mazda RX4            21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag        21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Pontiac Firebird     19.2    8  400.0  175  3.08  3.845  17.05   0   0     3
# Chrysler Imperial    14.7    8  440.0  230  3.23  5.345  17.42   0   0     3
# Dodge Challenger     15.5    8  318.0  150  2.76  3.520  16.87   0   0     3
# Hornet 4 Drive       21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Datsun 710           22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# AMC Javelin          15.2    8  304.0  150  3.15  3.435  17.30   0   0     3
# Volvo 142E           21.4    4  121.0  109  4.11  2.780  18.60   1   1     4
# Toyota Corona        21.5    4  120.1   97  3.70  2.465  20.01   1   0     3
# Merc 450SL           17.3    8  275.8  180  3.07  3.730  17.60   0   0     3
# Merc 450SLC          15.2    8  275.8  180  3.07  3.780  18.00   0   0     3
# Merc 450SE           16.4    8  275.8  180  3.07  4.070  17.40   0   0     3
# Porsche 914-2        26.0    4  120.3   91  4.43  2.140  16.70   0   1     5
# Duster 360           14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# Lotus Europa         30.4    4   95.1  113  3.77  1.513  16.90   1   1     5
# Camaro Z28           13.3    8  350.0  245  3.73  3.840  15.41   0   0     3
# Merc 230             22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# Hornet Sportabout    18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#                      carb  LOF_Value
# model
# Ferrari Dino            6   1.587094
# Maserati Bora           8   1.570968
# Valiant                 1   1.432937
# Honda Civic             2   1.237937
# Merc 240D               2   1.229866
# Toyota Corolla          1   1.195461
# Fiat 128                1   1.173683
# Fiat X1-9               1   1.167617
# Cadillac Fleetwood      4   1.159139
# Ford Pantera L          4   1.142798
# Lincoln Continental     4   1.128107
# Merc 280C               4   1.127728
# Merc 280                4   1.127189
# Mazda RX4               4   1.041947
# Mazda RX4 Wag           4   1.041947
# Pontiac Firebird        2   1.041303
# Chrysler Imperial       4   1.031167
# Dodge Challenger        2   1.030133
# Hornet 4 Drive          1   1.026977
# Datsun 710              1   1.024865
# AMC Javelin             2   1.014205
# Volvo 142E              2   1.008551
# Toyota Corona           1   0.984568
# Merc 450SL              3   0.974878
# Merc 450SLC             3   0.974647
# Merc 450SE              3   0.974647
# Porsche 914-2           2   0.967056
# Duster 360              4   0.964717
# Lotus Europa            2   0.959718
# Camaro Z28              4   0.952798
# Merc 230                2   0.942760
# Hornet Sportabout       2   0.923277

# %%
# # Eliminate rows with LOF score > 1.3
df4 = df4[df4['LOF_Value'] <= 1.3]
df4 = df4.sort_values(by='LOF_Value', ascending=False)
df4
# Out:
#                       mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# model
# Honda Civic          30.4    4   75.7   52  4.93  1.615  18.52   1   1     4
# Merc 240D            24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# Toyota Corolla       33.9    4   71.1   65  4.22  1.835  19.90   1   1     4
# Fiat 128             32.4    4   78.7   66  4.08  2.200  19.47   1   1     4
# Fiat X1-9            27.3    4   79.0   66  4.08  1.935  18.90   1   1     4
# Cadillac Fleetwood   10.4    8  472.0  205  2.93  5.250  17.98   0   0     3
# Ford Pantera L       15.8    8  351.0  264  4.22  3.170  14.50   0   1     5
# Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   0   0     3
# Merc 280C            17.8    6  167.6  123  3.92  3.440  18.90   1   0     4
# Merc 280             19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
# Mazda RX4 Wag        21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Mazda RX4            21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Pontiac Firebird     19.2    8  400.0  175  3.08  3.845  17.05   0   0     3
# Chrysler Imperial    14.7    8  440.0  230  3.23  5.345  17.42   0   0     3
# Dodge Challenger     15.5    8  318.0  150  2.76  3.520  16.87   0   0     3
# Hornet 4 Drive       21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Datsun 710           22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# AMC Javelin          15.2    8  304.0  150  3.15  3.435  17.30   0   0     3
# Volvo 142E           21.4    4  121.0  109  4.11  2.780  18.60   1   1     4
# Toyota Corona        21.5    4  120.1   97  3.70  2.465  20.01   1   0     3
# Merc 450SL           17.3    8  275.8  180  3.07  3.730  17.60   0   0     3
# Merc 450SE           16.4    8  275.8  180  3.07  4.070  17.40   0   0     3
# Merc 450SLC          15.2    8  275.8  180  3.07  3.780  18.00   0   0     3
# Porsche 914-2        26.0    4  120.3   91  4.43  2.140  16.70   0   1     5
# Duster 360           14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# Lotus Europa         30.4    4   95.1  113  3.77  1.513  16.90   1   1     5
# Camaro Z28           13.3    8  350.0  245  3.73  3.840  15.41   0   0     3
# Merc 230             22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# Hornet Sportabout    18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#                      carb  LOF_Value
# model
# Honda Civic             2   1.237937
# Merc 240D               2   1.229866
# Toyota Corolla          1   1.195461
# Fiat 128                1   1.173683
# Fiat X1-9               1   1.167617
# Cadillac Fleetwood      4   1.159139
# Ford Pantera L          4   1.142798
# Lincoln Continental     4   1.128107
# Merc 280C               4   1.127728
# Merc 280                4   1.127189
# Mazda RX4 Wag           4   1.041947
# Mazda RX4               4   1.041947
# Pontiac Firebird        2   1.041303
# Chrysler Imperial       4   1.031167
# Dodge Challenger        2   1.030133
# Hornet 4 Drive          1   1.026977
# Datsun 710              1   1.024865
# AMC Javelin             2   1.014205
# Volvo 142E              2   1.008551
# Toyota Corona           1   0.984568
# Merc 450SL              3   0.974878
# Merc 450SE              3   0.974647
# Merc 450SLC             3   0.974647
# Porsche 914-2           2   0.967056
# Duster 360              4   0.964717
# Lotus Europa            2   0.959718
# Camaro Z28              4   0.952798
# Merc 230                2   0.942760
# Hornet Sportabout       2   0.923277

# %%
df4.drop(columns=['LOF_Value'], inplace=True)

# %%
# Rebuild the models
X_train_lof, X_tes_lof, y_train_lof, y_test_lof = train_test_split(
    df4.iloc[:,1:], df4.iloc[:,0], test_size=0.1, random_state=42)

########### Linear Regression ############
regr = linear_model.LinearRegression()
regr.fit(X_train_lof, y_train_lof)
print('linear')
pred = regr.predict(X_test)
print(X_train.columns)
print(regr.coef_)
reg_r2_removed_lof = r2_score(y_test, pred)
reg_mse_removed_lof = mean_squared_error(y_test, pred)
print('**********')

#################### SVM ####################
regr_svm = make_pipeline(StandardScaler(), SVR(kernel='linear',C=1.0, epsilon=0.2))
regr_svm.fit(X_train_lof, y_train_lof)
pred = regr_svm.predict(X_test)
print('SVM')
print(X_train_lof.columns)
print(regr_svm.named_steps['svr'].coef_)
svm_r2_removed_lof = r2_score(y_test, pred)
svm_mse_removed_lof = mean_squared_error(y_test, pred)
print('**********')

#################### Gradient Boosting ####################
reg_gb = GradientBoostingRegressor(random_state=0)
reg_gb.fit(X_train_lof, y_train_lof)
pred = reg_gb.predict(X_test)
print('Gradient Boosting')
print(X_train_lof.columns)
print(reg_gb.feature_importances_)
gb_r2_removed_lof = r2_score(y_test, pred)
gb_mse_removed_lof = mean_squared_error(y_test, pred)
print('**********')
# Out:
# linear
# Index(['cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear', 'carb'], dtype='object')
# [-0.05797362  0.00461904 -0.00460456  0.34180882 -3.1441907   1.47949302
#  -0.14454454  3.03273688  1.17131605 -0.65849421]
# **********
# SVM
# Index(['cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear', 'carb'], dtype='object')
# [[-1.25811606 -0.84417163 -0.46977451  0.80524643 -1.4954124   0.50682326
#    0.42413907  0.98709411 -0.21579083 -1.12926536]]
# **********
# Gradient Boosting
# Index(['cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear', 'carb'], dtype='object')
# [1.27243682e-01 2.01626834e-01 1.44207240e-01 2.17378982e-03
#  4.92413422e-01 2.55048477e-02 2.01736142e-04 2.53005140e-05
#  1.68452409e-04 6.43469620e-03]
# **********

# %%
# compare metrics: no treatment VS "capped" VS "removed"
pd.DataFrame(
    {'LinearRegression':[reg_r2,reg_r2_capped,reg_r2_removed,reg_r2_removed_lof],
        'SVM':[svm_r2, svm_r2_capped, svm_r2_removed, svm_r2_removed_lof],
        'GradientBoosting':[gb_r2, gb_r2_capped, gb_r2_removed, gb_r2_removed_lof]},
    index=['R2', 'R2_capped', 'R2_removed', 'R2_removed_lof'])
# Out:
#                 LinearRegression       SVM  GradientBoosting
# R2                      0.838396  0.784034          0.876541
# R2_capped               0.840594  0.780404          0.880187
# R2_removed              0.714471  0.782641          0.722095
# R2_removed_lof          0.916821  0.873599          0.976491

# %%
pd.DataFrame(
    {'LinearRegression':[reg_mse,reg_mse_capped,reg_mse_removed,reg_mse_removed_lof],
     'SVM':[svm_mse, svm_mse_capped, svm_mse_removed, svm_mse_removed_lof],
     'GradientBoosting':[gb_mse, gb_mse_capped, gb_mse_removed, gb_mse_removed_lof]},
    index=['MSE', 'MSE_capped', 'MSE_removed', 'MSE_removed_lof'])
# Out:
#                  LinearRegression        SVM  GradientBoosting
# MSE                      9.935744  13.277986          7.590488
# MSE_capped               9.800564  13.501195          7.366320
# MSE_removed             17.554841  13.363656         17.086114
# MSE_removed_lof          5.113976   7.771392          1.445399

# %% [markdown]
# # Q1. What were the top 4 most influential features in the `regr` model above?

# %% [markdown]
# Depending on the answer, the most influential including negative and postive would be:
#
#
# Latest All Postive/Negative LOF Regr with Outliers Removed
# - wt: -3.1441907
# - am: 3.03273688
# - qsec: 1.47949302
# - gear: 1.17131605
#
# Latest All Postive LOF Regr with Outliers Removed:
# - am: 3.03273688
# - qsec: 1.47949302
# - gear: 1.17131605
# - drat: 0.34180882

# %% [markdown]
# # Q2. What was the most influential features in the `regr` model above?  What was the most influential feature in the `reg_gb` model above?

# %% [markdown]
# regr:
# - wt: -3.1441907
#
# reg_gb:
# - wt: 4.92413422e-01

# %% [markdown]
# # Q3. In the original data set (`df`) which car looks more like a *bivariate outlier* with respect to `disp` and `drat`?  *Masarati Bora*, *Ford Pantera L*, or the *Toyota Corolla*?

# %% [markdown]
# - Ford Pantera semms to be the most likely as a bivariate outlier to disp and drat. The Pantera stands out because of how it is from the other points, Maserati isn't for con

# %%
cars_of_interest = ['Maserati Bora', 'Ford Pantera L', 'Toyota Corolla']
df_subset = df.loc[cars_of_interest, ['disp', 'drat']]

plt.figure(figsize=(8, 6))
sns.scatterplot(x=df['disp'], y=df['drat'], label='All Cars', color='lightgray')

for car, row in df_subset.iterrows():
    plt.text(row['disp'] + 5, row['drat'], car, fontsize=9)

plt.title('Scatter Plot of Displacement (disp) vs Rear Axle Ratio (drat)')
plt.xlabel('Displacement (disp)')
plt.ylabel('Rear Axle Ratio (drat)')
plt.legend(loc='upper right')
plt.grid(True)
plt.show()

# %% [markdown]
# # Q4. Could the `scipy.stats.mstats.winsorize` function in Python be used to easily treat *only* the outliers we found with `sns.boxplot`?  Explain.

# %% [markdown]
# - Winsorize works by capping the certain percentile threshold across the entire distribution, it does not selectively treat specific points like we find from the IQR method. It more ideal for a uniform application across all points, not those identified as an outlier from the IQR, so I wouldn't recommend it.

# %% [markdown]
# # Q5. How does the "capping" the outliers affect model performance?  What happens if you change the `random_state` to 43 in the train/test split (and then re-build the models)?  What could be done to provide more robust error metrics?

# %% [markdown]
# - Capping limits the values of oultiers to a certain threshold, it can create more stability and reduce the variance in the model but has its drawbacks because it can create bias and some information loss if its capped to aggresively.
# - Compared to a normal state where every time the model is ran, different numbers and model performance will occur. By setting the random state to 43, you create reproducable scenario, different samples of both training and test data, and performance variability because of the new splits. When we set the split for capping to 43, the results are horrid.
# - Creating a ensemble methods (Bagging and Boosting), using a bootstrap sampling technique where you sample the whole different with replacement, or cross validation which divided the data a certain amount of times (k) and trains the model 'k' times.

# %%
X_train, X_test, y_train, y_test = train_test_split(
    df.iloc[:,1:], df.iloc[:,0], test_size=0.1, random_state=43)

# %%
########### Linear Regression ############
regr = linear_model.LinearRegression()
regr.fit(df2, y_train)
pred = regr.predict(X_test)
reg_r2_capped = r2_score(y_test, pred)
reg_mse_capped = mean_squared_error(y_test, pred)

#################### SVM ####################
regr_svm = make_pipeline(StandardScaler(), SVR(kernel='linear',C=1.0, epsilon=0.2))
regr_svm.fit(df2, y_train)
pred = regr_svm.predict(X_test)
svm_r2_capped = r2_score(y_test, pred)
svm_mse_capped = mean_squared_error(y_test, pred)

#################### Gradient Boosting ####################
reg_gb = GradientBoostingRegressor(random_state=0)
reg_gb.fit(df2, y_train)
pred = reg_gb.predict(X_test)
gb_r2_capped = r2_score(y_test, pred)
gb_mse_capped = mean_squared_error(y_test, pred)

# %%
# compare metrics: no treatment VS "capped"
pd.DataFrame(
    {'LinearRegression':[reg_r2,reg_r2_capped],
        'SVM':[svm_r2, svm_r2_capped],
        'GradientBoosting':[gb_r2, gb_r2_capped]},
    index=['R2', 'R2_capped'])
# Out:
#            LinearRegression       SVM  GradientBoosting
# R2                 0.838396  0.784034          0.876541
# R2_capped         -1.932476 -0.300214         -5.745071

# %%
pd.DataFrame(
    {'LinearRegression':[reg_mse,reg_mse_capped],
     'SVM':[svm_mse, svm_mse_capped],
     'GradientBoosting':[gb_mse, gb_mse_capped]},
    index=['MSE', 'MSE_capped'])
# Out:
#             LinearRegression        SVM  GradientBoosting
# MSE                 9.935744  13.277986          7.590488
# MSE_capped         34.110190  15.123926         78.457817

# %% [markdown]
# # Q6. *On average (given many different train/test splits)*, what modeling method is most affected by the removal of outliers in this data set?  Why?

# %% [markdown]
# - I believe it would be anything related to a linear or logistic regression output as a removal of an outlier can affect the slope greatly. Lets say you have one extreme outlier, it could alter the slope and intercept of the plotted line, creating a poor observation. Removing such points creates a more generalized observation to all the other fitted points.
# - Primarily that the assumption of linear functions relies on the data points, any extreme cases outside the normal will skew the output since these outliers will have a higher weight.

# %% [markdown]
# # Q7. What car has the 4th highest LOF value?  What attributes of this car showed up as univariate outliers according to our boxplots (IQR * 1.5 method)?

# %% [markdown]
# - Before removing LOF Values above 1.3, the honda civic had the 4th highest LOF out of all the cars. After removing, the 4th highest LOF score is the Fiat 128.
# - Fiat: qsec
# - Honda: wt

# %% [markdown]
# # Q8. In LOF method, there is a hyperparameter, what is it?  And what does it represent?

# %% [markdown]
# - The hyperparamater was the n_neighbors,and it defines how many points (neighbors) around each data point should be included in this comparison when calculating the LOF.

# %% [markdown]
# # Q9. Which outlier treatment worked best on this data set? [given the random_state=42 when splitting the data]

# %% [markdown]
# - Removing the outliers with LOF gave an output with the best results in terms of $R^{2}$ with MSE. The $R^{2}$ was 0.916821 for linear, 0.873599 for SVM, and 0.976491 for Gradient Boosting. All of which were at least .10 higher than the other methods. The MSE for LOF was 5.113976 for linear, 7.771392 for SVM and 1.445399 for Gradient Boosting. All of which is the lowest value comparatively in all categories.

# %% [markdown]
# # Q10. Which model is most likely to exhibit benign over-fitting?  If we theoretically put these models into production and tested them on new (previously unseen) cars, how might we detect that over-fitting?  Is it possible that what we previously treated as "outliers" would appear more "normal" in our data over time?

# %% [markdown]
# - The one model that we have that is likely to benign overfit would be the gradient boosting regressor. Having many splits could create an overfit scenario while having good performance.
# - If we were detect overfitting, looking at the $R^{2}$ and MSE would be a good indication. Seeing a decrease in $R^{2}$ accuracy and a increase in MSE after introducing the new data could be an indication of overfitting.
# - It depends on the data introduced, but yes it is possible for the oultiers to be considered normals, and even the some of the current data to be outliers. A concept drift would be the approach for this and occurs when the data distribution changes over time.
